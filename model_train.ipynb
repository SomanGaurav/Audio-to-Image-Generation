# %%
import numpy as np

# %%
X = np.load("token_embeddings.npy")

y1 = np.load("../data/clipl_embeds.npy")
y2 = np.load("../data/clipg_embeds.npy")
y3 = np.load("../data/t5_embeds.npy")

# %%
print(f"Shape of X :- {X.shape}")
print(f"Shape of y1 :- {y1.shape}")
print(f"Shape of y2 :- {y2.shape}")
print(f"Shape of y3 :- {y3.shape}")
# Out:
# Shape of X :- (10001, 10, 128)
# Shape of y1 :- (10001, 20, 768)
# Shape of y2 :- (10001, 20, 1280)
# Shape of y3 :- (10001, 20, 4096)

# %%
from skl
